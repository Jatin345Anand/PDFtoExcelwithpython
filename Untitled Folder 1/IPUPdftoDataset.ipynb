# %%
file = open("/Users/jatinanand/Documents/PythonWeekendAprilEve-master/StudentDataExtractionConsilidation/ResultIPU.txt")

# %%
Rowdata = file.read()

# %%
Rowdata
# Out:
# 'Aug 09, 2018 4:32:02 AM org.apache.pdfbox.pdmodel.graphics.color.PDDeviceRGB suggestKCMS\nINFO: To get higher rendering speed on java 8 oder 9,\nAug 09, 2018 4:32:02 AM org.apache.pdfbox.pdmodel.graphics.color.PDDeviceRGB suggestKCMS\nINFO:   use the option -Dsun.java2d.cmm=sun.java2d.cmm.kcms.KcmsServiceProvider\nAug 09, 2018 4:32:02 AM org.apache.pdfbox.pdmodel.graphics.color.PDDeviceRGB suggestKCMS\nINFO:   or call System.setProperty("sun.java2d.cmm", "sun.java2d.cmm.kcms.KcmsServiceProvider")\n(SCHEME OF EXAMINATIONS)\nRESULT\nPrepared Date: 05/04/2018\nDeclared Date:06/04/2018\nPage No.: 0001\nScheme of Programme Code: 027     Programme Name: BACHELOR OF TECHNOLOGY (COMPUTER SCIENCE AND ENGINEERING)      SchemeID: 190272015001     Sem./Year: 05 SEMESTER\nInstitution Code: 101     Institution: AMBEDKAR INSTITUTE OF ADVANCED COMMUNICATION TECHNOLOGIES & RESEARCH (FORMERLY AIT)\nS.No. Paper ID Code Subject Credit Type Exam Mode Kind Minor Major Max. Marks Pass Marks\n01 27301 ETCS
# ...

# %%
Data_1= Rowdata.split("\n")

# %%
Data_1
# Out:
# ['Aug 09, 2018 4:32:02 AM org.apache.pdfbox.pdmodel.graphics.color.PDDeviceRGB suggestKCMS',
#  'INFO: To get higher rendering speed on java 8 oder 9,',
#  'Aug 09, 2018 4:32:02 AM org.apache.pdfbox.pdmodel.graphics.color.PDDeviceRGB suggestKCMS',
#  'INFO:   use the option -Dsun.java2d.cmm=sun.java2d.cmm.kcms.KcmsServiceProvider',
#  'Aug 09, 2018 4:32:02 AM org.apache.pdfbox.pdmodel.graphics.color.PDDeviceRGB suggestKCMS',
#  'INFO:   or call System.setProperty("sun.java2d.cmm", "sun.java2d.cmm.kcms.KcmsServiceProvider")',
#  '(SCHEME OF EXAMINATIONS)',
#  'RESULT',
#  'Prepared Date: 05/04/2018',
#  'Declared Date:06/04/2018',
#  'Page No.: 0001',
#  'Scheme of Programme Code: 027     Programme Name: BACHELOR OF TECHNOLOGY (COMPUTER SCIENCE AND ENGINEERING)      SchemeID: 190272015001     Sem./Year: 05 SEMESTER',
#  'Institution Code: 101     Institution: AMBEDKAR INSTITUTE OF ADVANCED COMMUNICATION TECHNOLOGIES & RESEARCH (FORMERLY AIT)',
# ...

# %%
# DataRow_2 =[]
# for i in range(len(Data_1)):
#     if(len(Data_1[i])==11):
#         if(i.isdigit()):
            
        
#             DataRow_2.append([i])
#             DataRow_2.append(i)

Indexes=[]
for i in range(len(Data_1)):
    if(len(Data_1[i])==11):
        if(Data_1[i].isdigit()):
            print(i)
            Indexes.append(i)
            print(Data_1[i])
# Out:
# 74
# 00110102715
# 115
# 00210102715
# 156
# 00310102715
# 197
# 00410102715
# 238
# 00510102715
# 279
# 00610102715
# 320
# 00810102715
# 361
# 00910102715
# 402
# 01010102715
# 443
# 01110102715
# 512
# 01210102715
# 553
# 01310102715
# 594
# 01410102715
# 635
# 01510102715
# 676
# 01610102715
# 717
# 01710102715
# 758
# 01810102715
# 799
# 01910102715
# 840
# 02010102715
# 881
# 02210102715
# 950
# 02410102715
# 991
# 02710102715
# 1032
# 02810102715
# 1073
# 02910102715
# 1114
# 03010102715
# 1155
# 03110102715
# 1196
# 03510102715
# 1237
# 03610102715
# 1278
# 03710102715
# 1319
# 03810102715
# 1388
# 03910102715
# 1429
# 04010102715
# 1470
# 04110102715
# 1511
# 04210102715
# 1552
# 04410102715
# 1593
# 04510102715
# 1634
# 04610102715
# 1675
# 04810102715
# 1716
# 04910102715
# 1757
# 05210102715
# 1826
# 05510102715
# 1867
# 05710102715
# 1908
# 05810102715
# 1949
# 06010102715
# 1990
# 06110102715
# 2031
# 06210102715
# 2072
# 10110102715
# 2113
# 10210102715
# 2154
# ...

# %%
Indexes
# Out:
# [74,
#  115,
#  156,
#  197,
#  238,
#  279,
#  320,
#  361,
#  402,
#  443,
#  512,
#  553,
#  594,
#  635,
#  676,
#  717,
#  758,
#  799,
#  840,
#  881,
#  950,
#  991,
#  1032,
#  1073,
#  1114,
#  1155,
#  1196,
#  1237,
#  1278,
#  1319,
#  1388,
#  1429,
#  1470,
#  1511,
#  1552,
#  1593,
#  1634,
#  1675,
#  1716,
#  1757,
#  1826,
#  1867,
#  1908,
#  1949,
#  1990,
#  2031,
#  2072,
#  2113,
#  2154,
#  2195,
#  2264,
#  2305,
#  2346,
#  2387,
#  2428,
#  2469,
#  2510,
#  2551,
#  2592,
#  2633,
#  2702,
#  2743,
#  2784,
#  2825,
#  2866,
#  2907,
#  2948,
#  2989,
#  3030,
#  3071,
#  3140,
#  3181,
#  3222,
#  3263,
#  3304,
#  3345,
#  3386,
#  3427]

# %%
# for i in range(len(DataRow_2)):
#     print(i)
#     print(DataRow_2[i])
def PrintDatausingGivenIndexs(Data,SI,LI):
    i=SI
    L=[]
    while(i<(SI+41)):
        print(i)
        L.append(Data[i])
        i += 1
    return L
          
        

listofListofRow=[]
i2=0
for i in range(len(Indexes)-1):
    print(i,i+1)
    print(Indexes[i],Indexes[i+1])
    i2 += 1
    print(Data_1[Indexes[i]],Data_1[Indexes[i+1]])
    listofListofRow.append(PrintDatausingGivenIndexs(Data_1,Indexes[i],Indexes[i+1]))
    print('*******************')

# print(len(Indexes))

# print(i2)
# Out:
# 0 1
# 74 115
# 00110102715 00210102715
# 74
# 75
# 76
# 77
# 78
# 79
# 80
# 81
# 82
# 83
# 84
# 85
# 86
# 87
# 88
# 89
# 90
# 91
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 99
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# *******************
# 1 2
# 115 156
# 00210102715 00310102715
# 115
# 116
# 117
# 118
# 119
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# *******************
# 2 3
# 156 197
# 00310102715 00410102715
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# *******************
# 3 4
# 197 238
# 00410102715 00510102715
# 197
# 198
# 199
# 200
# 201
# 202
# 203
# 204
# 205
# ...

# %%
EnrollmentNumber = "EnrollmentNumber"
Name="Name"
SID="SID"
SchemaID="SchemaID"
PeparID1="PeparID1" 
PeparID2="PeparID2"
PeparID3="PeparID3" 
PeparID4="PeparID4"
PeparID5="PeparID5" 
PeparID6="PeparID6"
PeparID7="PeparID7" 
PeparID8="PeparID8"
PeparID9="PeparID9" 
PeparID10="PeparID10"
PeparID11="PeparID11" 
PeparID12="PeparID12"
PeparID13="PeparID13" 
PeparID14="PeparID14"
PeparID15="PeparID15" 
PeparID16="PeparID16"

Credit1= "Credit1" 
Credit2= "Credit2"
Credit3= "Credit3"
Credit4= "Credit4"
Credit5= "Credit5"
Credit6= "Credit6"
Credit7= "Credit7"
Credit8= "Credit8"
Credit9= "Credit9"
Credit10= "Credit10"
Credit11= "Credit11"
Credit12= "Credit12"
Credit13= "Credit13"
Credit14= "Credit14"
Credit15= "Credit15"
Credit16= "Credit16"

InternalM1 = "InternalM1"
InternalM2 = "InternalM2"
InternalM3 = "InternalM3"
InternalM4 = "InternalM4"
InternalM5 = "InternalM5"
InternalM6 = "InternalM6"
InternalM7 = "InternalM7"
InternalM8 = "InternalM8"
InternalM9 = "InternalM9"
InternalM10 = "InternalM10"
InternalM11 = "InternalM11"
InternalM12 = "InternalM12"
InternalM13 = "InternalM13"
InternalM14 = "InternalM14"
InternalM15 = "InternalM15"
InternalM16 = "InternalM16"

InternalM1a = "InternalM1a"
InternalM2a = "InternalM2a"
InternalM3a = "InternalM3a"
InternalM4a = "InternalM4a"
InternalM5a = "InternalM5a"
InternalM6a = "InternalM6a"
InternalM7a = "InternalM7a"
InternalM8a = "InternalM8a"
InternalM9a = "InternalM9a"
InternalM10a = "InternalM10a"
InternalM11a = "InternalM11a"
InternalM12a = "InternalM12a"
InternalM13a = "InternalM13a"
InternalM14a = "InternalM14a"
InternalM15a = "InternalM15a"
InternalM16a = "InternalM16a"

InternalM1b = "InternalM1b"
InternalM2b = "InternalM2b"
InternalM3b = "InternalM3b"
InternalM4b = "InternalM4b"

InternalM5b = "InternalM5b"
InternalM6b = "InternalM6b"
InternalM7b = "InternalM7b"
InternalM8b = "InternalM8b"
InternalM9b = "InternalM9b"
InternalM10b = "InternalM10b"
InternalM11b = "InternalM11b"
InternalM12b = "InternalM12b"
InternalM13b = "InternalM13b"
InternalM14b = "InternalM14b"
InternalM15b = "InternalM15b"
InternalM16b = "InternalM16b"

InternalM1c = "InternalM1c"
InternalM2c = "InternalM2c"
InternalM3c = "InternalM3c"
InternalM4c = "InternalM4c"
InternalM5c = "InternalM5c"
InternalM6c = "InternalM6c"
InternalM7c = "InternalM7c"
InternalM8c = "InternalM8c"
InternalM9c = "InternalM9c"
InternalM10c = "InternalM10c"
InternalM11c = "InternalM11c"
InternalM12c = "InternalM12c"
InternalM13c = "InternalM13c"
InternalM14c = "InternalM14c"
InternalM15c = "InternalM15c"
InternalM16c = "InternalM16c"

ExternalM1 = "ExternalM1"
ExternalM2 = "ExternalM2"
ExternalM3 = "ExternalM3"
ExternalM4 = "ExternalM4"
ExternalM5 = "ExternalM5"
ExternalM6 = "ExternalM6"
ExternalM7 = "ExternalM7"
ExternalM8 = "ExternalM8"
ExternalM9 = "ExternalM9"
ExternalM10 = "ExternalM10"
ExternalM11 = "ExternalM11"
ExternalM12 = "ExternalM12"
ExternalM13 = "ExternalM13"
ExternalM14 = "ExternalM14"
ExternalM15 = "ExternalM15"
ExternalM16 = "ExternalM16"

TotalM1 = "TotalM1"
TotalM2 = "TotalM2"
TotalM3 = "TotalM3"
TotalM4 = "TotalM4"
TotalM5 = "TotalM5"
TotalM6 = "TotalM6"
TotalM7 = "TotalM7"
TotalM8 = "TotalM8"
TotalM9 = "TotalM9"
TotalM10 = "TotalM10"
TotalM11 = "TotalM11"
TotalM12 = "TotalM12"
TotalM13 = "TotalM13"
TotalM14 = "TotalM14"
TotalM15 = "TotalM15"
TotalM16 = "TotalM16"
 
Grade1 = "Grade1"
Grade2 = "Grade2"
Grade3 = "Grade3"
Grade4 = "Grade4"
Grade5 = "Grade5"
Grade6 = "Grade6"
Grade7 = "Grade7"
Grade8 = "Grade8"
Grade9 = "Grade9"
Grade10 = "Grade10"
Grade11 = "Grade11"
Grade12 = "Grade12"
Grade13 = "Grade13"
Grade14 = "Grade14"
Grade15 = "Grade15"
Grade16 = "Grade16"
 
CSRemark = "CSRemark"
Sem1 = "Sem1"
Sem2 = "Sem2"
Sem3 = "Sem3"
Sem4 = "Sem4"
Sem5 = "Sem5"
Sem6 = "Sem6"
Sem7 = "Sem7"
Sem8 = "Sem8"

data = {EnrollmentNumber: 0, Name: '', SID: 0, SchemaID: 0,
        PeparID1: 0, Credit1: 0, InternalM1: 0,InternalM1a:0,InternalM1b:0,InternalM1c:0, ExternalM1: 0, TotalM1: 0, Grade1: '',
        PeparID2: 0, Credit2: 0, InternalM2: 0,InternalM2a:0,InternalM2b:0,InternalM2c:0, ExternalM2: 0, TotalM2: 0, Grade2: '',
        PeparID3: 0, Credit3: 0, InternalM3: 0,InternalM3a:0,InternalM3b:0,InternalM3c:0, ExternalM3: 0, TotalM3: 0, Grade3: '',
        PeparID4: 0, Credit4: 0, InternalM4: 0,InternalM4a:0,InternalM4b:0,InternalM4c:0, ExternalM4: 0, TotalM4: 0, Grade4: '',
        PeparID5: 0, Credit5: 0, InternalM5: 0,InternalM5a:0,InternalM5b:0,InternalM5c:0, ExternalM5: 0, TotalM5: 0, Grade5: '',
        PeparID6: 0, Credit6: 0, InternalM6: 0,InternalM6a:0,InternalM6b:0,InternalM6c:0, ExternalM6: 0, TotalM6: 0, Grade6: '',
        PeparID7: 0, Credit7: 0, InternalM7: 0,InternalM7a:0,InternalM7b:0,InternalM7c:0, ExternalM7: 0, TotalM7: 0, Grade7: '',
        PeparID8: 0, Credit8: 0, InternalM8: 0,InternalM8a:0,InternalM8b:0,InternalM8c:0, ExternalM8: 0, TotalM8: 0, Grade8: '',
        PeparID9: 0, Credit9: 0, InternalM9: 0,InternalM9a:0,InternalM9b:0,InternalM9c:0, ExternalM9: 0, TotalM9: 0, Grade9: '',
        PeparID10: 0, Credit10: 0, InternalM10: 0,InternalM10a:0,InternalM10b:0,InternalM10c:0, ExternalM10: 0, TotalM10: 0, Grade10: '',
        PeparID11: 0, Credit11: 0, InternalM11: 0,InternalM11a:0,InternalM11b:0,InternalM11c:0, ExternalM11: 0, TotalM11: 0, Grade11: '',
        PeparID12: 0, Credit12: 0, InternalM12: 0,InternalM12a:0,InternalM12b:0,InternalM12c:0, ExternalM12: 0, TotalM12: 0, Grade12: '',
        PeparID13: 0, Credit13: 0, InternalM13: 0,InternalM13a:0,InternalM13b:0,InternalM13c:0, ExternalM13: 0, TotalM13: 0, Grade13: '',
        PeparID14: 0, Credit14: 0, InternalM14: 0,InternalM14a:0,InternalM14b:0,InternalM14c:0, ExternalM14: 0, TotalM14: 0, Grade14: '',
        PeparID15: 0, Credit15: 0, InternalM15: 0,InternalM15a:0,InternalM15b:0,InternalM15c:0, ExternalM15: 0, TotalM15: 0, Grade15: '',
        PeparID16: 0, Credit16: 0, InternalM16: 0,InternalM16a:0,InternalM16b:0,InternalM16c:0, ExternalM16: 0, TotalM16: 0, Grade16: '',
        CSRemark: 0, Sem1: None, Sem2: None,Sem3: None,Sem4: None,Sem5: None, Sem6: None ,Sem7:None,Sem8:None}
 
def RemoveSID(s1):
    return s1[s1.index(':',0,len(s1))+2:len(s1)]

def RemoveShemaID(s2):
    return s2[s2.index(':',0,len(s2))+2:len(s2)]

def GetPeparID(s3):
    return s3[:s3.index('(',0,len(s3))]

def GetCredit(s3):
    return s3[s3.index('(',0,len(s3))+1:s3.index(')',0,len(s3))]

def GetInternalExternal(s4):
    return [s4.split(" ")[1],s4.split(" ")[3]]

def GetTotal(s5):
    return s5[:s5.index('(',0,len(s5))]

def GetGrade(s5):
    return s5[s5.index('(',0,len(s5))+1:s5.index(')',0,len(s5))]

LISTOFROW=[]
def GenerateListofDictionory(S):
    global data
    global LISTOFROW
    data['EnrollmentNumber'] = S[0]
    LISTOFROW.append(S[0])
    data['Name'] = S[1]
    LISTOFROW.append(S[1])
    data['SID'] = RemoveSID(S[2])
    LISTOFROW.append(RemoveSID(S[2]))
    data['SchemaID'] = RemoveShemaID(S[3])
    LISTOFROW.append(RemoveShemaID(S[3]))
    data['PeparID1'] = GetPeparID(S[4])
    LISTOFROW.append(GetPeparID(S[4]))
    data['Credit1'] = GetCredit(S[4])
    LISTOFROW.append(GetCredit(S[4]))
    data['InternalM1'] = GetInternalExternal(S[5])[0]
    LISTOFROW.append(GetInternalExternal(S[5])[0])
    data['ExternalM1'] = GetInternalExternal(S[5])[1]
    LISTOFROW.append(GetInternalExternal(S[5])[1])
    data['TotalM1'] = GetTotal(S[6])
    LISTOFROW.append(GetTotal(S[6]))
    data['Grade1'] = GetGrade(S[6])
    data['PeparID2'] = GetPeparID(S[7])
    data['Credit2'] = GetCredit(S[7])
    data['InternalM2'] = GetInternalExternal(S[8])[0]
    data['ExternalM2'] = GetInternalExternal(S[8])[1]
    data['TotalM2'] = GetTotal(S[9])
    data['Grade2'] = GetGrade(S[9])
    data['PeparID3'] = GetPeparID(S[10])
    data['Credit3'] = GetCredit(S[10])
    data['InternalM3'] = GetInternalExternal(S[11])[0]
    data['ExternalM3'] = GetInternalExternal(S[11])[1]
    data['TotalM3'] = GetTotal(S[12])
    data['Grade3'] = GetGrade(S[12])
    data['PeparID4'] = GetPeparID(S[13])
    data['Credit4'] = GetCredit(S[13])
    data['InternalM4'] = GetInternalExternal(S[14])[0]
    data['ExternalM4'] = GetInternalExternal(S[14])[1]
    data['TotalM4'] = GetTotal(S[15])
    data['Grade4'] = GetGrade(S[15])
    data['PeparID5'] = GetPeparID(S[16])
    data['Credit5'] = GetCredit(S[16])
    data['InternalM5'] = GetInternalExternal(S[17])[0]
    data['ExternalM5'] = GetInternalExternal(S[17])[1]
    data['TotalM5'] = GetTotal(S[18])
    data['Grade5'] = GetGrade(S[18])
    data['PeparID6'] = GetPeparID(S[19])
    data['Credit6'] = GetCredit(S[19])
    data['InternalM6'] = GetInternalExternal(S[20])[0]
    data['ExternalM6'] = GetInternalExternal(S[20])[1]
    data['TotalM6'] = GetTotal(S[21])
    data['Grade6'] = GetGrade(S[21])
    data['PeparID7'] = GetPeparID(S[22])
    data['Credit7'] = GetCredit(S[22])
    data['InternalM7'] = GetInternalExternal(S[23])[0]
    data['ExternalM7'] = GetInternalExternal(S[23])[1]
    data['TotalM7'] = GetTotal(S[24])
    data['Grade7'] = GetGrade(S[24])
    data['PeparID8'] = GetPeparID(S[25])
    data['Credit8'] = GetCredit(S[25])
    data['InternalM8'] = GetInternalExternal(S[26])[0]
    data['ExternalM8'] = GetInternalExternal(S[26])[1]
    data['TotalM8'] = GetTotal(S[27])
    data['Grade8'] = GetGrade(S[27])
    data['PeparID9'] = GetPeparID(S[28])
    data['Credit9'] = GetCredit(S[28])
    data['InternalM9'] = GetInternalExternal(S[29])[0]
    data['ExternalM9'] = GetInternalExternal(S[29])[1]
    data['TotalM9'] = GetTotal(S[30])
    data['Grade9'] = GetGrade(S[30])
    data['PeparID10'] = GetPeparID(S[31])
    data['Credit10'] = GetCredit(S[31])
    data['InternalM10'] = GetInternalExternal(S[32])[0]
    data['ExternalM10'] = GetInternalExternal(S[32])[1]
    data['TotalM10'] = GetTotal(S[33])
    data['Grade10'] = GetGrade(S[33])
    data['PeparID11'] = GetPeparID(S[34])
    data['Credit11'] = GetCredit(S[34])
    data['InternalM11'] = GetInternalExternal(S[35])[0]
    data['ExternalM11'] = GetInternalExternal(S[35])[1]
    data['TotalM11'] = GetTotal(S[36])
    data['Grade11'] = GetGrade(S[36])
    data['PeparID12'] = GetPeparID(S[37])
    data['Credit12'] = GetCredit(S[37])
    data['InternalM12'] = GetInternalExternal(S[38])[0]
    data['ExternalM12'] = GetInternalExternal(S[38])[1]
    data['TotalM12'] = GetTotal(S[39])
    data['Grade12'] = GetGrade(S[39])

    data['CSRemark'] = S[40]
    return data

# GenerateListofDictionory(SingleDataRow.split("\n"))

def CreartKeyList(D):
    temp = []
    dictKeylist = []
    for key, value in D.items():
        temp = key
        dictKeylist.append(temp)
    return dictKeylist

def CreatList(DICT):
    
    dictlist=[]
    temp=[]
    for key, value in DICT.items():
        temp = value
        dictlist.append(temp)
    return dictlist


# ListofDictionory=[]
# for i in range(len(listofListofRow)-1):
#     ANS=GenerateListofDictionory(listofListofRow[i])
#     A=CreatList(ANS)
#     ListofDictionory.append(A)

print(GenerateListofDictionory(listofListofRow[47]))
print(len(listofListofRow))
print(len(ListofDictionory))

import pandas as pd
# df = pd.DataFrame(ListofDictionory)
# print(len(ListofDictionory))

# print(ListofDictionory)
# Out:
# {'EnrollmentNumber': '10210102715', 'Name': 'JAGDEEP SINGH', 'SID': '190000085386', 'SchemaID': '190272015001', 'PeparID1': '27301', 'Credit1': '4', 'InternalM1': '15', 'InternalM1a': 0, 'InternalM1b': 0, 'InternalM1c': 0, 'ExternalM1': '46', 'TotalM1': '61', 'Grade1': 'B+', 'PeparID2': '98301', 'Credit2': '1', 'InternalM2': '20', 'InternalM2a': 0, 'InternalM2b': 0, 'InternalM2c': 0, 'ExternalM2': '48', 'TotalM2': '68', 'Grade2': 'A', 'PeparID3': '27303', 'Credit3': '4', 'InternalM3': '20', 'InternalM3a': 0, 'InternalM3b': 0, 'InternalM3c': 0, 'ExternalM3': '53', 'TotalM3': '73', 'Grade3': 'A', 'PeparID4': '28303', 'Credit4': '4', 'InternalM4': '21', 'InternalM4a': 0, 'InternalM4b': 0, 'InternalM4c': 0, 'ExternalM4': '32', 'TotalM4': '53', 'Grade4': 'B', 'PeparID5': '27307', 'Credit5': '4', 'InternalM5': '20', 'InternalM5a': 0, 'InternalM5b': 0, 'InternalM5c': 0, 'ExternalM5': '45', 'TotalM5': '65', 'Grade5': 'A', 'PeparID6': '99311', 'Credit6': '3', 'InternalM6': '19', 'InternalM6a'
# ...

# %%
# AboveData=''
# from collections import Counter 
# for i in Data_1:
    
#     AboveData += i 
#     if(i == DataRow_2[0][0]):
        
#         print(DataRow_2[0])
#         break
    
    
 

    
        
        
        ListofDictionory
# Out:
#   File "<ipython-input-106-fb463e70abef>", line 17
#     ListofDictionory
#     ^
# IndentationError: unexpected indent

# %%
# for data in Data_1:
#     if len(data) == 11:
#         print(data)

DataRow_2[0][
    0]
# Out:
# '00110102715'

# %%
AboveData
# Out:
# 'Aug 09, 2018 4:32:02 AM org.apache.pdfbox.pdmodel.graphics.color.PDDeviceRGB suggestKCMSINFO: To get higher rendering speed on java 8 oder 9,Aug 09, 2018 4:32:02 AM org.apache.pdfbox.pdmodel.graphics.color.PDDeviceRGB suggestKCMSINFO:   use the option -Dsun.java2d.cmm=sun.java2d.cmm.kcms.KcmsServiceProviderAug 09, 2018 4:32:02 AM org.apache.pdfbox.pdmodel.graphics.color.PDDeviceRGB suggestKCMSINFO:   or call System.setProperty("sun.java2d.cmm", "sun.java2d.cmm.kcms.KcmsServiceProvider")(SCHEME OF EXAMINATIONS)RESULTPrepared Date: 05/04/2018Declared Date:06/04/2018Page No.: 0001Scheme of Programme Code: 027     Programme Name: BACHELOR OF TECHNOLOGY (COMPUTER SCIENCE AND ENGINEERING)      SchemeID: 190272015001     Sem./Year: 05 SEMESTERInstitution Code: 101     Institution: AMBEDKAR INSTITUTE OF ADVANCED COMMUNICATION TECHNOLOGIES & RESEARCH (FORMERLY AIT)S.No. Paper ID Code Subject Credit Type Exam Mode Kind Minor Major Max. Marks Pass Marks01 27301 ETCS301 ALGORITHMS DESIGN AND AN
# ...

# %%
# LoLofRowStudent=[]
# i=0
# j=0
# for i in Data_1:
    
print(Rowdata)
# Out:
# Aug 09, 2018 4:32:02 AM org.apache.pdfbox.pdmodel.graphics.color.PDDeviceRGB suggestKCMS
# INFO: To get higher rendering speed on java 8 oder 9,
# Aug 09, 2018 4:32:02 AM org.apache.pdfbox.pdmodel.graphics.color.PDDeviceRGB suggestKCMS
# INFO:   use the option -Dsun.java2d.cmm=sun.java2d.cmm.kcms.KcmsServiceProvider
# Aug 09, 2018 4:32:02 AM org.apache.pdfbox.pdmodel.graphics.color.PDDeviceRGB suggestKCMS
# INFO:   or call System.setProperty("sun.java2d.cmm", "sun.java2d.cmm.kcms.KcmsServiceProvider")
# (SCHEME OF EXAMINATIONS)
# RESULT
# Prepared Date: 05/04/2018
# Declared Date:06/04/2018
# Page No.: 0001
# Scheme of Programme Code: 027     Programme Name: BACHELOR OF TECHNOLOGY (COMPUTER SCIENCE AND ENGINEERING)      SchemeID: 190272015001     Sem./Year: 05 SEMESTER
# Institution Code: 101     Institution: AMBEDKAR INSTITUTE OF ADVANCED COMMUNICATION TECHNOLOGIES & RESEARCH (FORMERLY AIT)
# S.No. Paper ID Code Subject Credit Type Exam Mode Kind Minor Major Max. Marks Pass Marks
# ...
